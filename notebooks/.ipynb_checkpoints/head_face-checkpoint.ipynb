# %%
import os
import shutil
import pandas as pd
from sklearn.model_selection import train_test_split
from map_boxes import mean_average_precision_for_boxes
import pandas as pd
import random
import yaml
# Out:
# Couldn't import fast version of function compute_overlap, will use slow one. Check cython intallation

# %% [markdown]
# # Разбиение датасета на train, val

# %%
dataset_path = "../data/image-deduplication_hhf_new/"

# %%
files = os.listdir(dataset_path + 'train_i')
print(len(files))
# Out:
# 4708

# %%
train_images_names, test_images_names = train_test_split(files, test_size=0.2, random_state=22)
print(len(train_images_names), len(test_images_names))
# Out:
# 3766 942

# %%
for test_image in test_images_names:
    shutil.copy(os.path.join(dataset_path, 'train_i', test_image), os.path.join(dataset_path, 'images/val/'))
    shutil.copy(os.path.join(dataset_path, 'train_l', test_image.split('.')[0]) + '.txt', os.path.join(dataset_path, 'labels/val/'))

# %%
for train_image in train_images_names:
    shutil.copy(os.path.join(dataset_path, 'train_i', train_image), os.path.join(dataset_path, 'images/train/'))
    shutil.copy(os.path.join(dataset_path, 'train_l', train_image.split('.')[0]) + '.txt', os.path.join(dataset_path, 'labels/train/'))

# %%
#валидация 
print(len(os.listdir(dataset_path + 'images/train/')))
print(len(os.listdir(dataset_path + 'images/val/')))
# Out:
# 3766
# 942

# %%
print(len(os.listdir(dataset_path + 'labels/train/')))
print(len(os.listdir(dataset_path + 'labels/val/')))
# Out:
# 3766
# 942

# %% [markdown]
# # Обучение

# %%
# !python3 ../yolov7/train.py --workers 8 --device 0 --batch-size 4 --data ../data/image-deduplication_hhf_new/dataset.yaml --img 416 416 --cfg cfg/training/yolov7.yaml --weights '../yolo_models/yolov7_training.pt' --name yolov7_hhf_new --hyp data/hyp.scratch.p5.yaml
# Out:
# train: weights=yolov5m.pt, cfg=, data=../data/image-deduplication_hhf_crop//dataset.yaml, hyp=../yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../yolov5/runs/train, name=yolov5m_hhf_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# Python 3.7.0 required by YOLOv5, but Python 3.6.9 is currently installed
# YOLOv5 🚀 2022-8-3 Python-3.6.9 torch-1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 2060, 5935MiB)
#
# ...

# %% [markdown]
# # Подготовка решения

# %%
# !rm -R ../yolov7/runs/detect/exp_hhf_res
# Out:
# rm: невозможно удалить '../yolov5/runs/detect/exp_hhf_res': Нет такого файла или каталога

# %%
# !python3 ../yolov7/detect_hhf.py --weights ../yolov7/runs/train/yolov7_hhf_new4/weights/best.pt --img 416 --conf 0.2 --source ../yolov7/runs/detect/exp_hhf --project ../yolov7/runs/detect --name exp_hhf_res --save-txt --save-conf --iou-thres 0.35 --exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=True, img_size=416, iou_thres=0.35, max_det=1000, name='exp_hhf_res', no_trace=False, nosave=False, project='../yolov7/runs/detect', save_conf=True, save_txt=True, source='../yolov7/runs/detect/exp_hhf', update=False, view_img=False, weights=['../yolov7/runs/train/yolov7_hhf_new4/weights/best.pt'])
# YOLOR 🚀 v0.1-104-g36ce6b2 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 2060, 5934.5625MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36487166 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# tensor(1852., device='cuda:0')
# 1 head, Done. (14.8ms) Inference, (16.4ms) NMS
# Done. (0.168s)
# Done. (0.194s)
# tensor(622., device='cuda:0')
# 1 head, Done. (15.2ms) Inference, (1.0ms) NMS
# Done. (0.255s)
# ...

# %% [markdown]
# # Формирование решения

# %%
def get_soliton_labels_df_simple_solution(path_to_txt_folder):
  simple_solution = []
  class_names = {1:2, 0:1}
  for detection_file in os.listdir(path_to_txt_folder):
    img_name = detection_file.split('.')[0] + '.jpg'
    with open(path_to_txt_folder + detection_file, 'r') as f:
      data = f.read()
      data = [i for i in data.split('\n') if i != '']
    for line in data:
      val = [float(i) for i in line.split()]
      cls, xywh, conf = val[0], val[1:5], val[5]
      center_x, center_y, width, height = xywh
      xmin = center_x - (width / 2)
      xmax = center_x + (width / 2)
      ymin = center_y - (height / 2)
      ymax = center_y + (height / 2)
      simple_solution.append([img_name, class_names[cls], conf, xmin, xmax, ymin, ymax])
  return simple_solution

# %%
simple_solution = get_soliton_labels_df_simple_solution('../yolov7/runs/detect/exp_hhf_res/labels/')
simple_solution = pd.DataFrame(simple_solution, columns=['ImageID', 'LabelName', 'Conf', 'XMin', 'XMax', 'YMin', 'YMax'])

# %%
simple_solution.to_csv("sample_solution_hhf_yolo.csv", sep=';', index=False)
